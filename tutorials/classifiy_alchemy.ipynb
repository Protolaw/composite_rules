# %%
import pandas as pd

# %%
df = pd.read_csv('../reference/n1_classified_alchemical_rules_neg.tsv', sep='\t')
df
# Out:
#                                       Alchemical_rule  output_reactants_num  \
# 0   [C;D3:1]-[C;D2:2]-[N;D2:3]=[N;D2+:4]>>[C;D3:1]...                     2
# 1   [C;D2:1]-[C;D2:2]-[N;D2:3]=[N;D2+:4]>>[N;D1-:3...                     2
# 2   [C;D2:1]-[C;D3:2](=[O;D1:3])-[N;D2:4]-[C;D2:5]...                     2
# 3   [C;D2:1]-[C;D2:2]=[O;D1:3]>>[C;D2:1]-[C;D3:2](...                     1
# 4   [C;D2:1]-[C;D3:2](=[O;D1:3])-[N;D3:4](-[C;D2:5...                     2
# ..                                                ...                   ...
# 59  [C;D3:1]-[O;D2:2]-[C;D2:3]-[C;D1:4]>>[C;D2:3](...                     2
# 60  [C;D4:1]-[C;D2:2]-[N;D1:3]>>[C;D4:1]-[C;D3:2](...                     1
# 61  [C;D4:1]-[C;D2:2]-[N;D2:3]=[N;D2+:4]>>[C;D4:1]...                     2
# 62  [C;D4:1]-[C;D2:2]=[O;D1:3]>>[C;D4:1]-[C;D3:2](...                     1
# 63  [O;D2:1]-[N;D2:2]-[C;D2:3]-[C;D2:4]>>[O;D2:1]-...                     2
#
#     popularity  route_ids_size  \
# ...

# %%
# Out:
#                                         Alchemical_rule  popularity  \
# 3     [C;D3:1]-[C;D3:2](=[O;D1:3])-[N;D2:4]-[C;D2:5]...          23
# 10    [C;D3:1]-[C;D2:2]-[N;D2:3]=[N;D2+:4]>>[C;D3:1]...          20
# 27    [C;D3:1]-[C;D2:2]-[N;D3:3](-[C;D2:4])-[C;D2:5]...          17
# 44    [C;D3:1]-[O;D2:2]-[C;D2:3]-[C;D2:4]>>[C;D2:3](...          13
# 61    [C;D3:1]-[C;D2:2]-[O;D2:3]-[C;D3:4]>>[C;D3:1]-...          10
# ...                                                 ...         ...
# 6902  [C;D4:1]-[C;D3:2](=[O;D1:3])-[N;D2:4]-[C;D2:5]...           1
# 6921  [C;D4:1]-[C;D3:2](=[O;D1:3])-[N;D3:4](-[C;D2:5...           1
# 6986  [C;D4:1]-[S;D4:2](=[O;D1:3])(=[O;D1:4])-[N;D2:...           1
# 7736  [N;D3:1]-[C;D3:2]:1:[C;D2:3]:[C;D3:4](-[C;D1:5...           1
# 8684  [O;D2:1]-[N;D2:2]-[C;D2:3]-[C;D2:4]>>[O;D2:1]-...           1
#
#       route_ids_size                                          Reference  \
# 3                 23  6,543,1168,1257,1571,1706,2142,2398,2839,3268,...
# ...

# %%
neg_num = 61

smarts(df.iloc[neg_num]['Alchemical_rule'])
